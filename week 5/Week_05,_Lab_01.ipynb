# %% [markdown]
# # Part 1: Histogram Equalization
#
# Histogram equalization improves contrast in images by redistributing the intensity values to make the histogram as flat as possible.

# %%
import cv2
import matplotlib.pyplot as plt

# Read a grayscale image
image = cv2.imread("C:/Users/sudob/OneDrive/Desktop/week5/images/images.jpg", cv2.IMREAD_GRAYSCALE)

# Apply histogram equalization
equalized_image = cv2.equalizeHist(image)

# Create figure
plt.figure(figsize=(10, 5))

# ---- Original Image ----
plt.subplot(2, 2, 1)
plt.imshow(image, cmap='gray')
plt.title('Original Image')
plt.axis('off')

# Histogram of Original Image
# ravel() flattens the 2D image matrix into a 1D array
# so we can compute its histogram
plt.subplot(2, 2, 2)
plt.hist(image.ravel(), 256, [0, 256])
plt.title('Histogram (Original)')

# ---- Equalized Image ----
plt.subplot(2, 2, 3)
plt.imshow(equalized_image, cmap='gray')
plt.title('Equalized Image')
plt.axis('off')

# Histogram of Equalized Image
plt.subplot(2, 2, 4)
plt.hist(equalized_image.ravel(), 256, [0, 256])
plt.title('Histogram (Equalized)')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\sudob\AppData\Local\Temp\ipykernel_16648\3273636489.py:23: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(image.ravel(), 256, [0, 256])
# C:\Users\sudob\AppData\Local\Temp\ipykernel_16648\3273636489.py:34: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(equalized_image.ravel(), 256, [0, 256])

# %% [markdown]
# ## Explanation of `ravel()`
#
# The `ravel()` function from NumPy flattens a multi-dimensional array into a one-dimensional array. In the case of images, it is used to convert the 2D image matrix into a 1D array for easy histogram plotting.
#
# ---
#
# ## Task 1
#
# 1. Apply histogram equalization to an image and observe the effect on contrast.
# 2. Compare the histograms before and after equalization.
# 3. Discuss why histogram equalization improves contrast in images with poor lighting.

# %% [markdown]
# ## 1. Apply Histogram Equalization and Observe the Effect
#
# ### Using OpenCV

# %%
import cv2
import matplotlib.pyplot as plt

# Read grayscale image
image = cv2.imread("C:/Users/sudob/OneDrive/Desktop/week5/images/images.jpg", cv2.IMREAD_GRAYSCALE)

# Apply histogram equalization
equalized_image = cv2.equalizeHist(image)

# Display images
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.imshow(image, cmap='gray')
plt.title("Original Image")
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(equalized_image, cmap='gray')
plt.title("Equalized Image")
plt.axis('off')

plt.show()

# %% [markdown]
# ### Observation
#
# - The equalized image appears brighter and clearer.
# - Dark regions become more visible.
# - Overall contrast increases.
# - Details hidden in shadows or low-light areas become easier to see.

# %% [markdown]
# ## 2. Compare Histograms Before and After Equalization
#
# ### Add Histogram Plots

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.hist(image.ravel(), 256, [0,256])
plt.title("Histogram (Original)")

plt.subplot(1,2,2)
plt.hist(equalized_image.ravel(), 256, [0,256])
plt.title("Histogram (Equalized)")

plt.show()
# Out:
# C:\Users\sudob\AppData\Local\Temp\ipykernel_16648\894929665.py:4: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(image.ravel(), 256, [0,256])
# C:\Users\sudob\AppData\Local\Temp\ipykernel_16648\894929665.py:8: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(equalized_image.ravel(), 256, [0,256])

# %% [markdown]
# ### Comparison
#
# #### Before Equalization
#
# - Histogram is concentrated in a narrow range.
# - Pixel intensities are clustered (e.g., mostly dark values).
# - Indicates poor contrast.
#
# #### After Equalization
#
# - Histogram spreads across a wider intensity range (0–255).
# - Pixel values are more evenly distributed.
# - Indicates improved contrast.

# %% [markdown]
# ## 3. Why Histogram Equalization Improves Contrast in Poor Lighting
#
# ### In Poorly Lit Images
#
# - Pixel values are concentrated in a small intensity range (often dark).
# - There is little difference between neighboring pixel values.
# - The image looks dull or flat.
#
# ---
#
# ###  What Histogram Equalization Does
#
# - It redistributes pixel intensity values.
# - It stretches frequently occurring intensity ranges.
# - It spreads the histogram across the full range (0–255).
# - It increases the dynamic range of pixel intensities.
#
# ---
#
# ###  Result
#
# - Dark pixels become darker where needed.
# - Bright pixels become brighter.
# - The difference between regions increases.
# - Human visual perception improves because contrast increases.
#
# ---
#
# ### In Simple Terms
#
# Histogram equalization spreads out the most frequent intensity values, allowing areas of lower contrast to gain higher contrast.

# %% [markdown]
# # Part 2: Histogram Equalization on Color Images
#
# ## Step 2: Applying Histogram Equalization to Color Channels Separately
#
# When working with color images, histogram equalization can be applied to individual color channels (Red, Green, Blue) separately.

# %%
import cv2
import matplotlib.pyplot as plt

# Read color image
color_image = cv2.imread("C:/Users/sudob/OneDrive/Desktop/week5/images/images.jpg")

# Split into B, G, R channels
b, g, r = cv2.split(color_image)

# Apply histogram equalization to each channel
equalized_b = cv2.equalizeHist(b)
equalized_g = cv2.equalizeHist(g)
equalized_r = cv2.equalizeHist(r)

# Merge channels back
equalized_color_image = cv2.merge([equalized_b, equalized_g, equalized_r])

# Display images
plt.figure(figsize=(10,5))

# Original Image
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(color_image, cv2.COLOR_BGR2RGB))
plt.title('Original Color Image')
plt.axis('off')

# Equalized Image
plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(equalized_color_image, cv2.COLOR_BGR2RGB))
plt.title('Equalized Color Image (Per Channel)')
plt.axis('off')

plt.show()

# %% [markdown]
# ## Task 2
#
# ### 1. Perform Histogram Equalization on the Color Channels Separately (Red, Green, Blue)

# %%
import cv2
import matplotlib.pyplot as plt

# Read color image
color_image = cv2.imread("C:/Users/sudob/OneDrive/Desktop/week5/images/images.jpg")

# Split into Blue, Green, Red channels
b, g, r = cv2.split(color_image)

# Apply histogram equalization to each channel
equalized_b = cv2.equalizeHist(b)
equalized_g = cv2.equalizeHist(g)
equalized_r = cv2.equalizeHist(r)

# Merge channels back
equalized_image = cv2.merge([equalized_b, equalized_g, equalized_r])

# Display results
plt.figure(figsize=(10,5))

# Original Image
plt.subplot(1,2,1)
plt.imshow(cv2.cvtColor(color_image, cv2.COLOR_BGR2RGB))
plt.title("Original Image")
plt.axis("off")

# Equalized Image
plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(equalized_image, cv2.COLOR_BGR2RGB))
plt.title("Equalized Image (Per Channel)")
plt.axis("off")

plt.show()

# %% [markdown]
# ## 2. Observe the Changes in Color Balance
#
#  **Observations:**
#
# After applying histogram equalization separately on each RGB channel:
#
# - The overall contrast increases.
# - Brightness distribution becomes more balanced.
# - Some colors may appear slightly unnatural.
# - The image may show color distortion.
# - Color tones may shift because each channel is adjusted independently.
#
# ---
#
#  **Why Does Color Change Happen?**
#
# When equalization is applied to each channel separately:
#
# - Red, Green, and Blue intensities are modified independently.
# - The relationship between the channels changes.
# - Since colors depend on the combination of RGB values, this affects the final color appearance.
#
# For example:
#
# - If the red channel is stretched more than others, the image may appear reddish.
# - If green changes more, the image may look greener.

# %% [markdown]
# # Part 3: Histogram Matching (Specification)
#
# Histogram matching transforms the histogram of an input image to match a target histogram from another image. This is useful for matching brightness and contrast between two images.
#
# ---
#
# ## Step 3: Applying Histogram Matching
#
# ### Using `skimage` (Recommended Method)

# %%
import cv2
import numpy as np
from skimage import exposure
import matplotlib.pyplot as plt

# Read two grayscale images
image_source = cv2.imread("C:/Users/sudob/OneDrive/Desktop/week5/images/images.jpg", cv2.IMREAD_GRAYSCALE)
image_target = cv2.imread("C:/Users/sudob/OneDrive/Desktop/week5/images/Images(1).jpg", cv2.IMREAD_GRAYSCALE)

# Perform histogram matching
matched_image = exposure.match_histograms(image_source, image_target)

# Display results
plt.figure(figsize=(15,5))

# Source Image
plt.subplot(3,3,1)
plt.imshow(image_source, cmap='gray')
plt.title('Source Image')
plt.axis('off')

plt.subplot(3,3,2)
plt.hist(image_source.ravel(), 256, [0,256])
plt.title('Histogram (Source)')

# Target Image
plt.subplot(3,3,4)
plt.imshow(image_target, cmap='gray')
plt.title('Target Image')
plt.axis('off')

plt.subplot(3,3,5)
plt.hist(image_target.ravel(), 256, [0,256])
plt.title('Histogram (Target)')

# Matched Image
plt.subplot(3,3,7)
plt.imshow(matched_image, cmap='gray')
plt.title('Matched Image')
plt.axis('off')

plt.subplot(3,3,8)
plt.hist(matched_image.ravel(), 256, [0,256])
plt.title('Histogram (Matched)')

plt.show()
# Out:
# C:\Users\sudob\AppData\Local\Temp\ipykernel_16648\3345725416.py:23: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(image_source.ravel(), 256, [0,256])
# C:\Users\sudob\AppData\Local\Temp\ipykernel_16648\3345725416.py:33: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(image_target.ravel(), 256, [0,256])
# C:\Users\sudob\AppData\Local\Temp\ipykernel_16648\3345725416.py:43: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(matched_image.ravel(), 256, [0,256])

# %% [markdown]
# ## Explanation of `exposure.match_histograms()`
#
# The `exposure.match_histograms()` function from **skimage** adjusts the pixel intensities of a source image so that its histogram matches that of a target image. It is useful for ensuring visual consistency between images in terms of contrast and brightness.
#
# ---
#
# ## Task 3
#
# ### 1. Choose Two Images (Source and Target)
# - **Source image**: The image you want to modify.
# - **Target image**: The image whose histogram will be used as reference.
#
# ---
#
# ### 2. Apply Histogram Matching

# %%
import cv2
from skimage import exposure
import matplotlib.pyplot as plt

# Read images in grayscale
source = cv2.imread("C:/Users/sudob/OneDrive/Desktop/week5/images/images.jpg", cv2.IMREAD_GRAYSCALE)
target = cv2.imread("C:/Users/sudob/OneDrive/Desktop/week5/images/Images(1).jpg", cv2.IMREAD_GRAYSCALE)

# Apply histogram matching
matched = exposure.match_histograms(source, target)

# Display images
plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
plt.imshow(source, cmap='gray')
plt.title("Source Image")
plt.axis('off')

plt.subplot(1,3,2)
plt.imshow(target, cmap='gray')
plt.title("Target Image")
plt.axis('off')

plt.subplot(1,3,3)
plt.imshow(matched, cmap='gray')
plt.title("Matched Image")
plt.axis('off')

plt.show()

# %% [markdown]
# ## What Happens After Histogram Matching?
#
# - The intensity distribution of the source image changes.
# - The histogram of the source becomes similar to the target histogram.
# - Brightness and contrast adjust according to the target image.
#
# ---
#
# ##  3. How Histogram Matching Affects Visual Appearance
#
# ###  Visual Changes:
#
# - The overall brightness of the source image may increase or decrease.
# - Contrast changes to resemble the target image.
# - Dark images can become brighter if the target is bright.
# - Bright images can become darker if the target is dark.
# - The image appearance becomes similar to the target image.

# %% [markdown]
# ## Explanation
#
# Histogram matching works by:
#
# - Transforming pixel intensity values.
# - Matching the cumulative distribution function (CDF) of the source image to that of the target image.
# - Adjusting intensity values so both histograms look similar.
#
# In this way, the source image is modified to follow the same intensity distribution as the target image.

# %% [markdown]
# # Part 4: Combining Histogram Equalization and Matching
#
# ## Task 4
#
# ### 1. First, Equalize the Histogram of a Source Image

# %% [markdown]
# ## Task 4 Solution
#
# ### Step 1: Equalize the Source Image
# ### Step 2: Apply Histogram Matching Using Target Image

# %%
import cv2
from skimage import exposure
import matplotlib.pyplot as plt

# Read images in grayscale
source = cv2.imread("C:/Users/sudob/OneDrive/Desktop/week5/images/images.jpg", cv2.IMREAD_GRAYSCALE)
target = cv2.imread("C:/Users/sudob/OneDrive/Desktop/week5/images/Images(1).jpg", cv2.IMREAD_GRAYSCALE)

# Step 1: Histogram Equalization
equalized_source = cv2.equalizeHist(source)

# Step 2: Histogram Matching on Equalized Image
matched_image = exposure.match_histograms(equalized_source, target)

# Display results
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.imshow(source, cmap='gray')
plt.title("Original Source")
plt.axis('off')

plt.subplot(1,3,2)
plt.imshow(equalized_source, cmap='gray')
plt.title("After Equalization")
plt.axis('off')

plt.subplot(1,3,3)
plt.imshow(matched_image, cmap='gray')
plt.title("After Equalization + Matching")
plt.axis('off')

plt.show()

# %% [markdown]
# ## 3. Discussion: How Equalization Followed by Matching Affects Appearance
#
# ###  First: Histogram Equalization
#
# - Improves contrast.
# - Spreads pixel values across the full intensity range.
# - Enhances details in dark and bright regions.
# - Makes the image visually clearer.
#
# ---
#
# ###  Then: Histogram Matching
#
# - Adjusts the equalized image to resemble the target image.
# - Changes brightness and contrast again.
# - Forces the intensity distribution to follow the target histogram.
#
# ---
#
# ###  Overall Effect on the Original Image
#
# When equalization is followed by matching:
#
# - Contrast is first enhanced.
# - Then brightness and intensity distribution are reshaped.
# - The final image looks similar to the target image.
# - Some details may change depending on the target histogram.
# - The image may look very different from the original.
#
# ---
#
# ###  Key Understanding
#
# - Equalization improves contrast automatically.
# - Matching changes image appearance to follow another image.
# - Combining both means:
#   - **First enhance**, then **standardize to a reference**.
#
# This can sometimes:
#
# - Improve visibility.
# - Or slightly reduce the contrast gained from equalization (depending on the target image).
